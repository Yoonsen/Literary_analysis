# %% [markdown]
# # Undersøk korpus med metadata
#
# Notebook for å undersøke korpus med metadata

# %%
import nbtext as nb
from nbtext import Corpus
# %matplotlib inline

# %%
frank = nb.get_urn({'title':'frank%', 'author':"shelley%",'year':1800, 'next':250})

# %%
frank
# Out:
# [[2013013008321, 'Shelley, Mary Wollstonecraft', 'Frankenstein', 2012],
#  [2011072508006, 'Shelley, Mary Wollstonecraft', 'Frankenstein', 2004],
#  [2011110906074,
#   'Shelley, Mary Wollstonecraft',
#   'Frankenstein, eller Den moderne Promethevs',
#   2010],
#  [2013010708229,
#   'Shelley, Mary Wollstonecraft',
#   'Frankenstein, eller Den moderne Promethevs',
#   2005],
#  [2015052808135, 'Shelley, Mary Wollstonecraft', 'Frankenstein', 1976],
#  [2008022000084, 'Shelley, Mary Wollstonecraft', 'Frankenstein', 1995],
#  [2008011101010, 'Shelley, Mary Wollstonecraft', 'Frankenstein', 1993]]

# %%
franken_navn  = nb.navn(frank[1])
franken_navn = {n:franken_navn[n] for n in franken_navn if franken_navn[n] > 4}
print([x for x in franken_navn])
# Out:
# ['Agatha', 'Agrippa', 'Akk', 'Beaufort', 'Blanc', 'Clerval', 'Clervals', 'Cornelius', 'Elizabeth', 'Elizabeths', 'England', 'Ernest', 'Felix', 'Frankenstein', 'Genéve', 'Gud', 'Henry', 'Ingolstadt', 'Italia', 'Justine', 'KAPITTEL', 'Lacey', 'Livorno', 'London', 'M', 'Margaret', 'Mont', 'Moritz', 'Mr', 'Nei', 'Oxford', 'Paris', 'Rhinen', 'Safie', 'Sveits', 'The', 'Victor', 'Walton', 'William']

# %%
fnavn = [ 'Elizabeth', 'Justine', 'Felix', 'Clerval', 'din', 'vesenet','Gud', 'Guds','skapningen', 'skapning', 'vesen', 
         'monster', 'Victor',  'Henry',  'William',  'Safie',  'Agatha',  'Elizabeths', 'Ernest',   'Margaret',  'Frankenstein', 'Lacey',  'Agrippa', 'Moritz', 'Walton', 'Beaufort', 'Clervals', 'Cornelius']

# %%
frank[1]
# Out:
# [2008022000084, 'Shelley, Mary Wollstonecraft', 'Frankenstein', 1995]

# %%
fwords = nb.get_freq(frank[1][0], top=150000, cutoff=1)

# %%
fwords['vesen']
# Out:
# 43

# %%
nb.make_network_graph??

# %%
network = nb.make_network(frank[1], franken_navn)

# %%
n0 = nb.make_network(frank[0], check_navn(nb.navn(frank[0]), 3))

n1 = nb.make_network(frank[1], check_navn(nb.navn(frank[1]), 3))

n2 = nb.make_network(frank[2], check_navn(nb.navn(frank[2]), 3))

n3 = nb.make_network(frank[3], check_navn(nb.navn(frank[3]), 3))

n4 = nb.make_network(frank[4], check_navn(nb.navn(frank[4]), 3))

n5 = nb.make_network(frank[5], check_navn(nb.navn(frank[5]), 3))

# %%
def check_navn(navn, limit=2):
    return {x:navn[x] for x in navn if navn[x] > limit and x.upper() != x}

# %%
nb.draw_graph_centrality(n2, k=0.5)
# Out:
# True

# %%
nb.draw_graph_centrality(n3, k=0.5)
# Out:
# True

# %%
nb.draw_graph_centrality(n4, k=1.0)
# Out:
# True

# %%
nb.draw_graph_centrality(network, k=0.5)
# Out:
# True

# %%
nb.central_betweenness_characters(network)
# Out:
# [('Genéve', 0.1536708650305142),
#  ('Elizabeth', 0.1376180071794107),
#  ('Clerval', 0.11797820631153964),
#  ('Frankenstein', 0.07878991392149286),
#  ('Victor', 0.05813841778754061),
#  ('Paris', 0.05809823134384536),
#  ('William', 0.05612238660484274),
#  ('Felix', 0.03362322840393016),
#  ('England', 0.03170048819171626),
#  ('Justine', 0.030192736442736436)]

# %%
[nb.central_betweenness_characters(n) for n in [n0, n1, n2, n3, n4, n5]  ]
# Out:
# [[('Frankenstein', 0.5595238095238095),
#   ('Victor', 0.3404761904761905),
#   ('Henry', 0.153968253968254),
#   ('Sveits', 0.1285714285714286),
#   ('Genéve', 0.11666666666666668),
#   ('Felix', 0.1142857142857143),
#   ('Safie', 0.1142857142857143),
#   ('Elizabeth', 0.09603174603174605),
#   ('Justine', 0.07380952380952381),
#   ('William', 0.045238095238095244)],
#  [('Genéve', 0.15897371860958062),
#   ('Clerval', 0.15274293831098532),
#   ('Elizabeth', 0.13777217979970302),
#   ('Sveits', 0.11978553124565085),
#   ('England', 0.09784754409854497),
#   ('Frankenstein', 0.07033781642171119),
#   ('Frankrike', 0.06222956411067919),
#   ('Victor', 0.047531429134192504),
#   ('Paris', 0.04277159410022013),
#   ('Justine', 0.03586331687672286)],
#  [('Frankenstein', 0.16905977479611717),
#   ('England', 0.11364047134273457),
#   ('Genéve', 0.10843549270392991),
#   ('Clerval', 0.10145610111984842),
#   ('William', 0.09698599359987935),
#   ('Elizabeth', 0.08834151153404153),
#   ('Sveits', 0.07944800850244864),
#   ('Gud', 0.07814542668593569),
#   ('Europa', 0.07150203787564567),
#   ('Victor', 0.05434776115679556)],
#  [('Frankenstein', 0.1689510448732231),
#   ('England', 0.10893194002416758),
#   ('Clerval', 0.09858680828959542),
#   ('Elizabeth', 0.09308332074408925),
#   ('Sveits', 0.09301233456535628),
#   ('William', 0.09120526254865044),
#   ('Genéve', 0.08621038373401135),
#   ('Gud', 0.08329663060281492),
#   ('Europa', 0.06926253445874526),
#   ('Victor', 0.06166202715458964)],
#  [('Gud', 0.22011463597732017),
#   ('Genéve', 0.15580481841252017),
#   ('Mr', 0.15091476000283438),
#   ('Frankenstein', 0.0923378835779715),
#   ('Clerval', 0.08780662031286497),
#   ('Elizabeth', 0.07722513963143389),
#   ('England', 0.0695000383084288),
#   ('Samlede', 0.06867305061559507),
#   ('William', 0.06379474009937176),
#   ('Mary', 0.04517473884893934)],
#  [('Genéve', 0.1848600655033665),
#   ('Clerval', 0.155682028881924),
#   ('Sveits', 0.13393073485634566),
#   ('Elizabeth', 0.12832121912804378),
#   ('England', 0.09654942774967101),
#   ('Frankrike', 0.06034311784315008),
#   ('Frankenstein', 0.053856043492803464),
#   ('Akk', 0.051761184124356846),
#   ('Justine', 0.0478272534543042),
#   ('Paris', 0.04270726022869055)]]

# %%
nb.central_characters(network)
# Out:
# [('Clerval', 0.6216216216216217),
#  ('Elizabeth', 0.5945945945945946),
#  ('Genéve', 0.5675675675675675),
#  ('Victor', 0.5135135135135136),
#  ('William', 0.4864864864864865),
#  ('Justine', 0.4594594594594595),
#  ('Frankenstein', 0.40540540540540543),
#  ('Akk', 0.40540540540540543),
#  ('Henry', 0.35135135135135137),
#  ('Sveits', 0.32432432432432434)]

# %%
skapning = nb.make_graph('skapning')

# %%
creation = make_graph('creature', lang='eng')

# %%
def make_graph(word, lang='nob'):
    import requests
    import networkx as nx
    import json
    result = requests.get("https://www.nb.no/sp_tjenester/beta/ngram_1/galaxies/query?terms={word}&corpus={lang}".format(word=word, lang=lang))
    G = nx.DiGraph()
    edgelist = []
    if result.status_code == 200:
        graph = json.loads(result.text)
        #print(graph)
        nodes = graph['nodes']
        edges = graph['links']
        for edge in edges:
            edgelist += [(nodes[edge['source']]['name'], nodes[edge['target']]['name'], abs(edge['value']))]
    #print(edgelist)
    G.add_weighted_edges_from(edgelist)
    return G

# %%
nb.draw_graph_centrality(creation, k=1)
# Out:
# True

# %%
nb.draw_graph_centrality(skapning)
# Out:
# True

# %%
import pandas as pd
df_creation = pd.DataFrame.from_dict(dict(nb.central_betweenness_characters(creation, n=500)), orient='index')

# %%
df_skapning = pd.DataFrame.from_dict(dict(nb.central_betweenness_characters(skapning, n=500)), orient='index')

# %%
nb.cloud(df_skapning)

# %%
nb.cloud(df_creation)

# %%
nb.central_betweenness_characters(creation, n=500)
# Out:
# [('creature', 0.5244949494949495),
#  ('plaything', 0.2446969696969697),
#  ('dependant', 0.24065656565656565),
#  ('confidant', 0.21717171717171718),
#  ('vassal', 0.19797979797979798),
#  ('crony', 0.1595959595959596),
#  ('reptile', 0.08484848484848485),
#  ('creator', 0.07373737373737374),
#  ('pensioner', 0.06388888888888888),
#  ('hireling', 0.06212121212121212),
#  ('moulder', 0.06212121212121212),
#  ('retainer', 0.05101010101010101),
#  ('tributary', 0.05101010101010101),
#  ('tool', 0.025252525252525252),
#  ('slave', 0.011111111111111112),
#  ('toy', 0.0),
#  ('pensionary', 0.0),
#  ('subordinate', 0.0),
#  ('servant', 0.0),
#  ('liegeman', 0.0),
#  ('insect', 0.0),
#  ('amphibian', 0.0),
#  ('mammal', 0.0),
#  ('bird', 0.0),
#  ('mercenary', 0.0),
#  ('crumble', 0.0),
#  ('ally', 0.0),
#  ('rot', 0.0),
#  ('puppet', 0.0),
#  ('precarious', 0.0),
#  ('counsellor', 0.0),
#  ('advisor', 0.0),
#  ('adviser', 0.0),
#  ('nursling', 0.0),
#  ('environing', 0.0),
#  ('Creator', 0.0),
#  ('sae', 0.0),
#  ('pet', 0.0),
#  ('sport', 0.0),
#  ('lord', 0.0),
#  ('overlord', 0.0),
#  ('suzerain', 0.0),
#  ('maker', 0.0),
#  ('sustainer', 0.0),
#  ('preserver', 0.0),
#  ('rationis', 0.0)]
