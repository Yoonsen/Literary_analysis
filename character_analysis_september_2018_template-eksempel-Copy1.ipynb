# %% [markdown]
# # Make a character network from a text

# %%
import dhlab.nbtext as nb
import dhlab.module_update as mu
import dhlab.graph_networkx_louvain as gnl
from dhlab.nbtext import Corpus

# %%
mu.css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Merriweather|Shippori+Mincho|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Shippori+Mincho';
# 	font-size:1.1em;
# 	color: DarkSlateGray;
# }
#
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
#
#
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
import networkx as nx
import requests
import pandas as pd

def check_navn(navn, limit=2, remove='Ja Nei Nå Dem De Deres Unnskyld Ikke Ah Hmm'.split()):
    """Removes all items in navn with frequency below limit and words in all case as well as all words in list 'remove'"""
    r = {x:navn[x] for x in navn if navn[x] > limit and x.upper() != x and not x in remove}
    return r

def check_edges(G, weight=1):    
    return nx.Graph([edge for edge in G.edges(data=True) if edge[2]['weight'] >= weight])

def freq(urn, words):
    params = {'urn':urn, 'words':words}
    r = requests.post("https://api.nb.no/ngram/freq", json=params)
    return dict(r.json())

def book_count(urns):
    params = {'urns':urns}
    r = requests.post("https://api.nb.no/ngram/book_count", json=params)
    return dict(r.json())

# %% [markdown]
# # Select a list of books
#
# Add metadata in order to select a book.

# %%
bøker = nb.get_urn({'title':'krig%', 'author':"tols%", 'trans':'', 'year':1800, 'next':250, 'limit':130})

for b in bøker:
    print(book_count([b[0]]), b)
# Out:
# {2007111900105: 163601} [2007111900105, 'Tolstoj, L.N.', 'Krig og fred', 1993]
# {2007032801091: 91485} [2007032801091, 'Tolstoj, L.N.', 'Krig og fred', 1962]
# {2015110507062: 88222} [2015110507062, 'Tolstoj, L.N.', 'Krig og fred', 1928]
# {2007111904099: 133554} [2007111904099, 'Tolstoj, L.N.', 'Krig og fred', 1993]
# {2008042300036: 141243} [2008042300036, 'Tolstoj, L.N.', 'Krig og fred', 1951]
# {2014100308012: 90432} [2014100308012, 'Tolstoj, L.N.', 'Krig og fred', 1929]
# {2007050801009: 141332} [2007050801009, 'Tolstoj, L.N.', 'Krig og fred', 1968]
# {2011063022003: 173184} [2011063022003, 'Tolstoj, L.N.', 'Krig og fred', 1967]
# {2012011008041: 127143} [2012011008041, 'Tolstoj, L.N.', 'Krig og fred', 1951]
# {2011081020006: 163906} [2011081020006, 'Tolstoj, L.N.', 'Krig og fred', 1968]
# {2008101004071: 125257} [2008101004071, 'Tolstoj, L.N.', 'Krig og fred', 2000]
# {2008102204034: 133546} [2008102204034, 'Tolstoj, L.N.', 'Krig og fred', 2000]
# {2011063022004: 124729} [2011063022004, 'Tolstoj, L.N.', 'Krig og fred', 1967]
# {2008102200095: 163366} [2008102200095, 'Tolstoj, L.N.', 'Krig og fred', 2000]
# {} [2009042200103, 'Tolstoj, L.N.', 'Krig og fred', 2002]
# {2015091006105: 126615} [2015091006105, 'Tolstoj, L.N.', 'Krig og fred', 2004]
# {2007050800051: 99532} [2007050800051, 'Tolstoj, L.N.', 'Krig og fred', 1962]
# {2011061508082: 294884} [2011061508082, 'Tolstoj, L.N.', 'Krig og fred', 2008]
# {2008110400150: 157120} [2008110400150, 'Tolstoj, L.N.', 'Krig og fred', 2001]
# {2007041101090: 98936} [2007041101090, 'Tolstoj, L.N.', 'Krig og fred', 1962]
# {2014101408145: 100031} [2014101408145, 'Tolstoj, L.N.', 'Krig og fred', 1929]
# {2008011501085: 127646} [2008011501085, 'Tolstoj, L.N.', 'Krig og fred', 1993]
# {2011063023001: 163241} [2011063023001, 'Tolstoj, L.N.', 'Krig og fred', 1967]
# {2011061508081: 324509} [2011061508081, 'Tolstoj, L.N.', 'Krig og fred', 2008]
# {2011063022002: 179369} [2011063022002, 'Tolstoj, L.N.', 'Krig og fred', 1967]
# {2007041001053: 91212} [2007041001053, 'Tolstoj, L.N.', 'Krig og fred', 1962]
# {2008042400005: 122127} [2008042400005, 'Tolstoj, L.N.', 'Krig og fred', 1951]
# {2007051400011: 131527} [2007051400011, 'Tolstoj, L.N.', 'Krig og fred', 1968]
# {2011030308018: 168239} [2011030308018, 'Tolstoj, L.N.', 'Krig og fred', 2003]
# {2015091406029: 98414} [2015091406029, 'Tolstoj, L.N.', 'Krig og fred', 1929]
# {2007032601072: 102980} [2007032601072, 'Tolstoj, L.N.', 'Krig og fred', 1962]

# %%
book_count([b[0] for b in bøker])
# Out:
# {2007111900105: 163601,
#  2007032801091: 91485,
#  2015110507062: 88222,
#  2007111904099: 133554,
#  2008042300036: 141243,
#  2014100308012: 90432,
#  2007050801009: 141332,
#  2011063022003: 173184,
#  2012011008041: 127143,
#  2011081020006: 163906,
#  2008101004071: 125257,
#  2008102204034: 133546,
#  2011063022004: 124729,
#  2008102200095: 163366,
#  2015091006105: 126615,
#  2007050800051: 99532,
#  2011061508082: 294884,
#  2008110400150: 157120,
#  2007041101090: 98936,
#  2014101408145: 100031,
#  2008011501085: 127646,
#  2011063023001: 163241,
#  2011061508081: 324509,
#  2011063022002: 179369,
#  2007041001053: 91212,
#  2008042400005: 122127,
#  2007051400011: 131527,
#  2011030308018: 168239,
#  2015091406029: 98414,
#  2007032601072: 102980}

# %% [markdown]
# ### Assign a select book to variable 'book'

# %%
book =[2011061508081, 'Tolstoj, L.N.', 'Krig og fred', 2008]

# %% [markdown]
# Compute the candidates for characters - anything starting with a capital letter that could be a person name or place name. Print the topmost elements.

# %%
book_names_raw = nb.navn(book)
print('Number of objects === ', len(list(book_names_raw)), '\nSome examples ======= ', list(book_names_raw)[:20])
# Out:
# Number of objects ===  693
# Some examples =======  ['Adam', 'Adieu', 'Ah', 'Akhrosimova', 'Akk', 'Aleksander', 'Aleksanders', 'Aleksejevitsj', 'Aleksejevitsjs', 'Alfons', 'Allez', 'Allmektige', 'Allons', 'Alpatytsj', 'Amélie', 'Anarole', 'Anatole', 'Anatoles', 'Andre', 'Andrej']

# %% [markdown]
# ### Edit names, remove some words
#
# Rerun from here and change parameters

# %%
book_names = check_navn(book_names_raw, 20)
print([x for x in book_names])
# Out:
# ['Aleksander', 'Anatole', 'Andre', 'Andrej', 'Andrejevitsj', 'Andrejitsj', 'Andrejs', 'André', 'Anna', 'Austerlitz', 'Bagration', 'Balaga', 'Berg', 'Bezukhov', 'Bilibin', 'Bolkonskij', 'Bonaparte', 'Boris', 'Bourienne', 'Cest', 'Danilo', 'Denisov', 'Denisovs', 'Dmitrijevna', 'Dolgorukov', 'Dolokhov', 'Dolokhovs', 'Er', 'Gory', 'Gud', 'Guds', 'Har', 'Helene', 'Hippolyte', 'Hvem', 'Hvordan', 'Ilja', 'Jo', 'Julie', 'Kjære', 'Kom', 'Kuragin', 'Kutuzov', 'Kutuzovs', 'Liza', 'Lysyje', 'Majestet', 'Mamma', 'Mana', 'Maria', 'Marja', 'Mikhail', 'Mikhajlovna', 'Mile', 'Mon', 'Moskva', 'Napoleon', 'Natasja', 'Natasjas', 'Nesvitskij', 'Nikolaj', 'Nåvel', 'Otradnoje', 'Pavlovna', 'Petersburg', 'Petja', 'Pierre', 'Pierres', 'Rostov', 'Rostovs', 'Russland', 'Se', 'Sjinsjin', 'Sonja', 'Speranskij', 'Teljanin', 'Tikhon', 'Tusjin', 'Vasilij', 'Vasilijs', 'Vera', 'Vous', 'Vær', 'Weyrother', 'Wien', 'Zjerkov']

# %% [markdown]
# ## Create the network

# %%
network_raw = nb.make_network(book, book_names)

# %% [markdown]
# Remove edges with a weight (usually number of connections) less than weight.

# %%
network = check_edges(network_raw, weight=3)

# %%
nb.central_betweenness_characters(network)
# Out:
# [('Andrej', 0.1444974684589169),
#  ('Pierre', 0.09718282112350321),
#  ('Rostov', 0.05280597625990593),
#  ('Natasja', 0.04969941915341778),
#  ('Boris', 0.04646826162853766),
#  ('Nikolaj', 0.046351338035806496),
#  ('Moskva', 0.029516539878174312),
#  ('Maria', 0.028720169315572735),
#  ('Anatole', 0.02591445592773702),
#  ('Sonja', 0.022745916953137137)]

# %%
gnl.show_graph(network, fontsize=12)

# %%
gnl.show_communities(network)
# Out:
# Andrej-Bolkonskij :  Andrej, Bolkonskij, Kutuzov, Andre, Bonaparte, Bagration, Napoleon, Andrejs, Aleksander, Dolgorukov, Russland, Kutuzovs, Tusjin, Nesvitskij, Bilibin, Zjerkov, Austerlitz, Kjære, Weyrother, Mikhail, Speranskij, Wien, Majestet
#
# Natasja-Nikolaj :  Natasja, Nikolaj, Sonja, Jo, Dmitrijevna, Otradnoje, Natasjas, Ilja, Andrejitsj, Vera, Sjinsjin, Petja, Kom, Marja, Mamma, Danilo
#
# Rostov-Boris :  Rostov, Boris, Er, Denisov, Julie, Rostovs, Berg, Hvem, Mon, Denisovs, Teljanin
#
# Moskva-Maria :  Moskva, Maria, Anatole, Dolokhov, Mile, Mana, Bourienne, Andrejevitsj, Lysyje, Dolokhovs, Gory, Kuragin, Tikhon, Liza, André, Balaga
#
# Pierre-Anna :  Pierre, Anna, Vasilij, Petersburg, Gud, Hvordan, Helene, Mikhajlovna, Pavlovna, Har, Se, Vasilijs, Bezukhov, Guds, Pierres, Hippolyte, Nåvel, Cest, Vær, Vous

# %%
nb.get_urnkonk('Denisov',{'urns':[book[0]], 'before':12, "after":12,"size":20})
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011061508081' target='_blank' style='text-decoration:none'>Krig og fred, Tolstoj, L.N., 2008</a>
#                 </td>
#                 <td>, var innkvartert i den tyske landsbyen Salzeneck . Eskadronsjefen , nttmester</td>
#                 <td>Denisov</td>
#                 <td style='text-align:left'>, som var kjent i hele kavaleridivisjonen under navnet Vaska Denisov ,</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011061508081' target='_blank' style='text-decoration:none'>Krig og fred, Tolstoj, L.N., 2008</a>
#                 </td>
#                 <td>nttmester Denisov , som var kjent i hele kavaleridivisjonen under navnet Vaska</td>
#                 <td>Denisov</td>
#                 <td style='text-align:left'>, hadde fått seg anvist det beste kvarteret i hele landsbyen .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011061508081' target='_blank' style='text-decoration:none'>Krig og fred, Tolstoj, L.N., 2008</a>
#                 </td>
#                 <td>Macks nederlag , gikk livet fortsatt sin vante gang ved eskadronen .</td>
#                 <td>Denisov</td>
#                 <td style='text-align:left'>, som hadde vært ute og spilt kort hele natten , var</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011061508081' target='_blank' style='text-decoration:none'>Krig og fred, Tolstoj, L.N., 2008</a>
#                 </td>
#                 <td>tyskeren til fjøset og Rostov inn i stuen , hvor han og</td>
#                 <td>Denisov</td>
#                 <td style='text-align:left'>bodde .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011061508081' target='_blank' style='text-decoration:none'>Krig og fred, Tolstoj, L.N., 2008</a>
#                 </td>
#                 <td>Rostov kikket ut av vinduet og fikk øye på</td>
#                 <td>Denisov</td>
#                 <td style='text-align:left'>. Denisov var en liten mann med rødt ansikt , gnistrende svarte</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011061508081' target='_blank' style='text-decoration:none'>Krig og fred, Tolstoj, L.N., 2008</a>
#                 </td>
#                 <td>Rostov kikket ut av vinduet og fikk øye på Denisov .</td>
#                 <td>Denisov</td>
#                 <td style='text-align:left'>var en liten mann med rødt ansikt , gnistrende svarte øyne ,</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011061508081' target='_blank' style='text-decoration:none'>Krig og fred, Tolstoj, L.N., 2008</a>
#                 </td>
#                 <td>- Å , er du alt oppe ? sa</td>
#                 <td>Denisov</td>
#                 <td style='text-align:left'>da han kom inn . - Jaså ! Og jeg har blakket</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011061508081' target='_blank' style='text-decoration:none'>Krig og fred, Tolstoj, L.N., 2008</a>
#                 </td>
#                 <td>ropte</td>
#                 <td>Denisov</td>
#                 <td style='text-align:left'>. - Snakk om å sitte i utur ! ... Så tort</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011061508081' target='_blank' style='text-decoration:none'>Krig og fred, Tolstoj, L.N., 2008</a>
#                 </td>
#                 <td>None</td>
#                 <td>Denisov</td>
#                 <td style='text-align:left'>rynket pannen , smilte og viste sine korte , sterke tenner og</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011061508081' target='_blank' style='text-decoration:none'>Krig og fred, Tolstoj, L.N., 2008</a>
#                 </td>
#                 <td>None</td>
#                 <td>Denisov</td>
#                 <td style='text-align:left'>fikk et enda morskere uttrykk i ansiktet .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011061508081' target='_blank' style='text-decoration:none'>Krig og fred, Tolstoj, L.N., 2008</a>
#                 </td>
#                 <td>Ute i forstuen sått</td>
#                 <td>Denisov</td>
#                 <td style='text-align:left'>sammenkrøpet på dørstokken med pipen i munnen og hørte på vaktmesterens rapport</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011061508081' target='_blank' style='text-decoration:none'>Krig og fred, Tolstoj, L.N., 2008</a>
#                 </td>
#                 <td>Kom så går vi . Jeg kom jo bare for å spørre</td>
#                 <td>Denisov</td>
#                 <td style='text-align:left'>om gårsdagens ordre . Har De fått den , Denisov ? spurte</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011061508081' target='_blank' style='text-decoration:none'>Krig og fred, Tolstoj, L.N., 2008</a>
#                 </td>
#                 <td>å spørre Denisov om gårsdagens ordre . Har De fått den ,</td>
#                 <td>Denisov</td>
#                 <td style='text-align:left'>? spurte han da de gikk gjennom forstuen .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011061508081' target='_blank' style='text-decoration:none'>Krig og fred, Tolstoj, L.N., 2008</a>
#                 </td>
#                 <td>Da Rostov kom tilbake , sått</td>
#                 <td>Denisov</td>
#                 <td style='text-align:left'>med en flaske vodka og en pølsesnabb foran seg og skrapet med</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011061508081' target='_blank' style='text-decoration:none'>Krig og fred, Tolstoj, L.N., 2008</a>
#                 </td>
#                 <td>None</td>
#                 <td>Denisov</td>
#                 <td style='text-align:left'>ble morsk på nytt , skulle til å rope et eller annet</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011061508081' target='_blank' style='text-decoration:none'>Krig og fred, Tolstoj, L.N., 2008</a>
#                 </td>
#                 <td>hvorfor står du der som et fugleskremsel, få vaktmesteren bort ! ropte</td>
#                 <td>Denisov</td>
#                 <td style='text-align:left'>til Lavrusjka . - Kan du ikke låne pengene av meg ,</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011061508081' target='_blank' style='text-decoration:none'>Krig og fred, Tolstoj, L.N., 2008</a>
#                 </td>
#                 <td>til Lavrusjka . - Kan du ikke låne pengene av meg ,</td>
#                 <td>Denisov</td>
#                 <td style='text-align:left'>? Jeg har nok av penger , sa Rostov og rødmet .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011061508081' target='_blank' style='text-decoration:none'>Krig og fred, Tolstoj, L.N., 2008</a>
#                 </td>
#                 <td>av mine venner , - nei det vil jeg ikke , brummet</td>
#                 <td>Denisov</td>
#                 <td style='text-align:left'>.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011061508081' target='_

# %%
node_freq = freq(book[0], list(network.nodes()))

# %%
#tot = sum(node_freq.values())
for e in node_freq:
    network.node[e]['weight'] = node_freq[e]#/tot

# %%
network.nodes(data=True)
# Out:
# NodeDataView({'Aleksander': {'weight': 36}, 'Andrej': {'weight': 734}, 'Andrejitsj': {'weight': 38}, 'Bagration': {'weight': 115}, 'Bolkonskij': {'weight': 108}, 'Bonaparte': {'weight': 81}, 'Boris': {'weight': 266}, 'Denisov': {'weight': 219}, 'Dolgorukov': {'weight': 39}, 'Ilja': {'weight': 42}, 'Kutuzov': {'weight': 169}, 'Moskva': {'weight': 142}, 'Napoleon': {'weight': 84}, 'Nikolaj': {'weight': 327}, 'Petersburg': {'weight': 109}, 'Pierre': {'weight': 895}, 'Rostov': {'weight': 561}, 'Russland': {'weight': 35}, 'Vasilij': {'weight': 164}, 'Anatole': {'weight': 209}, 'Andrejevitsj': {'weight': 26}, 'Andrejs': {'weight': 38}, 'André': {'weight': 23}, 'Anna': {'weight': 255}, 'Austerlitz': {'weight': 25}, 'Berg': {'weight': 74}, 'Bilibin': {'weight': 47}, 'Bourienne': {'weight': 79}, 'Cest': {'weight': 32}, 'Dmitrijevna': {'weight': 81}, 'Dolokhov': {'weight': 225}, 'Gory': {'weight': 27}, 'Gud': {'weight': 132}, 'Guds': {'weight': 39}, 'Helene': {'weight': 109}, 'Hippolyte': {'weight': 38}, 'Kuragin': {'weight': 35}, 'Kutuzovs': {'weight': 36}, 'Liza': {'weight': 23}, 'Lysyje': {'weight': 28}, 'Majestet': {'weight': 35}, 'Mana': {'weight': 38}, 'Maria': {'weight': 282}, 'Mikhail': {'weight': 23}, 'Mile': {'weight': 101}, 'Natasja': {'weight': 701}, 'Natasjas': {'weight': 41}, 'Nesvitskij': {'weight': 66}, 'Otradnoje': {'weight': 31}, 'Pavlovna': {'weight': 101}, 'Pierres': {'weight': 33}, 'Rostovs': {'weight': 54}, 'Sonja': {'weight': 289}, 'Speranskij': {'weight': 59}, 'Tusjin': {'weight': 61}, 'Vera': {'weight': 67}, 'Weyrother': {'weight': 27}, 'Wien': {'weight': 34}, 'Zjerkov': {'weight': 39}, 'Vasilijs': {'weight': 22}, 'Bezukhov': {'weight': 39}, 'Julie': {'weight': 54}, 'Mikhajlovna': {'weight': 123}, 'Denisovs': {'weight': 26}, 'Marja': {'weight': 34}, 'Petja': {'weight': 50}, 'Teljanin': {'weight': 25}, 'Danilo': {'weight': 29}})

# %%
nb.central_characters(network, n=len(network))
# Out:
# [('Andrej', 0.8507462686567164),
#  ('Pierre', 0.7611940298507462),
#  ('Rostov', 0.6268656716417911),
#  ('Moskva', 0.6119402985074627),
#  ('Nikolaj', 0.6119402985074627),
#  ('Natasja', 0.5970149253731343),
#  ('Boris', 0.5671641791044776),
#  ('Maria', 0.5522388059701493),
#  ('Bolkonskij', 0.47761194029850745),
#  ('Anna', 0.47761194029850745),
#  ('Anatole', 0.4626865671641791),
#  ('Sonja', 0.4626865671641791),
#  ('Petersburg', 0.44776119402985076),
#  ('Vasilij', 0.417910447761194),
#  ('Gud', 0.40298507462686567),
#  ('Dolokhov', 0.3880597014925373),
#  ('Mile', 0.34328358208955223),
#  ('Bonaparte', 0.3283582089552239),
#  ('Kutuzov', 0.3283582089552239),
#  ('Helene', 0.31343283582089554),
#  ('Napoleon', 0.29850746268656714),
#  ('Dmitrijevna', 0.29850746268656714),
#  ('Mikhajlovna', 0.29850746268656714),
#  ('Bagration', 0.2835820895522388),
#  ('Denisov', 0.2835820895522388),
#  ('Ilja', 0.2835820895522388),
#  ('Aleksander', 0.26865671641791045),
#  ('Bourienne', 0.26865671641791045),
#  ('Mana', 0.26865671641791045),
#  ('Andrejevitsj', 0.2537313432835821),
#  ('Andrejs', 0.2537313432835821),
#  ('Natasjas', 0.2537313432835821),
#  ('Otradnoje', 0.2537313432835821),
#  ('Rostovs', 0.2537313432835821),
#  ('Julie', 0.2537313432835821),
#  ('Andrejitsj', 0.23880597014925373),
#  ('Pavlovna', 0.23880597014925373),
#  ('Berg', 0.22388059701492538),
#  ('Lysyje', 0.22388059701492538),
#  ('Vera', 0.208955223880597),
#  ('Vasilijs', 0.208955223880597),
#  ('Bezukhov', 0.208955223880597),
#  ('Dolgorukov', 0.19402985074626866),
#  ('Gory', 0.19402985074626866),
#  ('Guds', 0.19402985074626866),
#  ('Russland', 0.1791044776119403),
#  ('Kuragin', 0.16417910447761194),
#  ('Kutuzovs', 0.16417910447761194),
#  ('Austerlitz', 0.14925373134328357),
#  ('Pierres', 0.14925373134328357),
#  ('Petja', 0.14925373134328357),
#  ('Bilibin', 0.13432835820895522),
#  ('Hippolyte', 0.13432835820895522),
#  ('Nesvitskij', 0.13432835820895522),
#  ('Zjerkov', 0.13432835820895522),
#  ('Mikhail', 0.11940298507462686),
#  ('Wien', 0.11940298507462686),
#  ('Denisovs', 0.11940298507462686),
#  ('Cest', 0.1044776119402985),
#  ('Speranskij', 0.1044776119402985),
#  ('Weyrother', 0.1044776119402985),
#  ('Majestet', 0.08955223880597014),
#  ('Tusjin', 0.08955223880597014),
#  ('Marja', 0.08955223880597014),
#  ('Teljanin', 0.05970149253731343),
#  ('André', 0.04477611940298507),
#  ('Liza', 0.04477611940298507),
#  ('Danilo', 0.04477611940298507)]
