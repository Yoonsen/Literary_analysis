# %%
import nbtext as nb
import requests
from IPython.display import HTML, display

# %%
def api():
    return requests.get('https://api.nb.no').json()

# %%
api()
# Out:
# {'_links': {'self': {'href': 'https://api.nb.no:443'},
#   'delivery_orders': {'href': 'https://api.nb.no:443/catalog/v1/delivery/orders{?page,size,sort,direction}',
#    'templated': True},
#   'dewey': {'href': 'https://api.nb.no:443/dewey/v1/list{?class,language}',
#    'templated': True},
#   'item': {'href': 'https://api.nb.no:443/catalog/v1/items/{id}/{?fields,expand}',
#    'templated': True},
#   'related_items': {'href': 'https://api.nb.no:443/catalog/v1/items/{id}/relatedItems',
#    'templated': True},
#   'content_fragments': {'href': 'https://api.nb.no:443/catalog/v1/items/{id}/contentfragments{?q,fragments,fragSize}',
#    'templated': True},
#   'metadata_mods': {'href': 'https://api.nb.no:443/catalog/v1/metadata/{id}/mods',
#    'templated': True},
#   'metadata_marcxml': {'href': 'https://api.nb.no:443/catalog/v1/metadata/{id}/marcxml',
#    'templated': True},
#   'metadata_dublincore': {'href': 'https://api.nb.no:443/catalog/v1/metadata/{id}/dublincore',
#    'templated': True},
#   'metadata_struct': {'href': 'https://api.nb.no:443/catalog/v1/metadata/{id}/struct',
#    'templated': True},
#   'jwplayer': {'href': 'https://api.nb.no:443/catalog/v1/playlist/{id}/jwplayer.rss{?offset,extent}',
#    'templated': True},
#   'presentation_manifest': {'href': 'https://api.nb.no:443/catalog/v1/iiif/{id}/manifest',
#    'templated': True},
#   'presentation_contentsearch': {'href': 'https://api.nb.no:443/catalog/v1/contentsearch/{id}/search{?q}',
#    'templated': True},
#   'reference_wiki': {'href': 'https://api.nb.no:443/catalog/v1/reference/{id}/wiki',
#    'templated': True},
#   'reference_ris': {'href': 'https://api.nb.no:443/catalog/v1/reference/{id}/ris',
#    'templated': True},
#   'reference_enw': {'href': 'https://api.nb.no:443/catalog/v1/reference/{id}/enw',
#    'templated': True},
#   'search': {'href': 'https://api.nb.no:443/catalog/v1/items{?q,page,size,sort,grouping,boost,should,aggs,searchType,topRight,bottomLeft,precision,explain,dq,digitalAccessibleOnly,filter,aq,snippets,fragments,fragSize,random,profile,expand}',
#    'templated': True},
#   'super_search': {'href': 'https://api.nb.no:443/catalog/v1/search{?q,page,size,sort,grouping,boost,should,aggs,searchType,topRight,bottomLeft,precision,explain,dq,digitalAccessibleOnly,filter,aq,snippets,fragments,fragSize,random,profile,expand,mediaTypeOrder,mediaTypeSize}',
#    'templated': True},
#   'typeahead_suggestions': {'href': 'https://api.nb.no:443/catalog/v1/typeahead/search{?q,mediaType,size,highlight}',
#    'templated': True},
#   'typeahead_suggestions_field': {'href': 'https://api.nb.no:443/catalog/v1/typeahead/{field}{?q,size,profile,filter}',
#    'templated': True},
#   'user_details': {'href': 'https://api.nb.no:443/me/v1'},
#   'user_collections': {'href': 'https://api.nb.no:443/me/v1/collections'},
#   'user_collection': {'href': 'https://api.nb.no:443/me/v1/collections/{collectionId}',
#    'templated': True},
#   'user_list': {'href': 'https://api.nb.no:443/me/v1/collections/{collectionId}/{resourceId}',
#    'templated': True}}}

# %%
def related(idd):
    return requests.get('https://api.nb.no:443/catalog/v1/metadata/{idd}/struct'.format(idd=idd)).text

# %%
related('URN:NBN:no-nb_digibok_2011110906074')
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><structMap xmlns:ns2="http://www.w3.org/1999/xlink"><div ID="DIV322" ORDER="322" ORDERLABEL="322" TYPE="COVER_FRONT_INSIDE"><hotspots/><resource HEIGHT="2951" ns2:href="URN:NBN:no-nb_digibok_2011110906074_I1" originalName="digibok_2011110906074_I1.jpg" SCANRESOLUTION="400" WIDTH="1790"/></div><div ID="DIV1" ORDER="1" ORDERLABEL="1" TYPE="PAGE"><hotspots/><resource HEIGHT="2914" ns2:href="URN:NBN:no-nb_digibok_2011110906074_0001" originalName="digibok_2011110906074_0001.jpg" SCANRESOLUTION="400" WIDTH="1733"/></div><div ID="DIV2" ORDER="2" ORDERLABEL="2" TYPE="BLANK_PAGE"><hotspots/><resource HEIGHT="2914" ns2:href="URN:NBN:no-nb_digibok_2011110906074_0002" originalName="digibok_2011110906074_0002.jpg" SCANRESOLUTION="400" WIDTH="1733"/></div><div ID="DIV3" ORDER="3" ORDERLABEL="3" TYPE="TITLE_PAGE"><hotspots/><resource HEIGHT="2916" ns2:href="URN:NBN:no-nb_digibok_2011110906074_0003" originalName="digibok_2011110906074_0003.jpg" SCANRESOLUTION="400" WIDTH="1732"/></div><div ID="DIV4" ORDER="4" ORDERLABEL="4" TYPE="PAGE"><hotspots/><resource HEIGHT="2916" ns2:href="URN:NBN:no-nb_digibok_2011110906074_0004" originalName="digibok_2011110906074_0004.jpg" SCANRESOLUTION="400" WIDTH="1732"/></div><div ID="DIV5" ORDER="5" ORDERLABEL="5" TYPE="PAGE"><hotspots/><resource HEIGHT="2914" ns2:href="URN:NBN:no-nb_digibok_2011110906074_0005" originalName="digibok_2011110906074_0005.jpg" SCANRESOLUTION="400" WIDTH="1717"/></div><div ID="DIV6" ORDER="6" ORDERLABEL="6" TYPE="PAGE"><hotspots/><resource HEIGHT="2914" ns2:href="URN:NBN:no-nb_digibok_2011110906074_0006" originalName="digibok_2011110906074_0006.jpg" SCANRESOLUTION="400" WIDTH="1717"/></div><div ID="DIV7" ORDER="7" ORDERLABEL="7" TYPE="PAGE"><hotspots/><resource HEIGHT="2916" ns2:href="URN:NBN:no-nb_digibok_2011110906074_0007" originalName="digibok_2011110906074_0007.jpg" SCANRESOLUTION="400" WIDTH="1725"/></div><div ID="DIV8" ORDER="8" ORDERLABEL="8" TYPE="PAGE"><hotspots/><resource HEIGHT="2916" ns2:href="URN:NBN:no-nb_digibok_2011110906074_0008" originalName="digibok_2011110906074_0008.jpg" SCANRESOLUTION="400" WIDTH="1725"/></div><div ID="DIV9" ORDER="9" ORDERLABEL="9" TYPE="PAGE"><hotspots/><resource HEIGHT="2913" ns2:href="URN:NBN:no-nb_digibok_2011110906074_0009" originalName="digibok_2011110906074_0009.jpg" SCANRESOLUTION="400" WIDTH="1722"/></div><div ID="DIV10" ORDER="10" ORDERLABEL="10" TYPE="PAGE"><hotspots/><resource HEIGHT="2913" ns2:href="URN:NBN:no-nb_digibok_2011110906074_0010" originalName="digibok_2011110906074_0010.jpg" SCANRESOLUTION="400" WIDTH="1722"/></div><div ID="DIV11" ORDER="11" ORDERLABEL="11" TYPE="PAGE"><hotspots/><resource HEIGHT="2913" ns2:href="URN:NBN:no-nb_digibok_2011110906074_0011" originalName="digibok_2011110906074_0011.jpg" SCANRESOLUTION="400" WIDTH="1712"/></div><div ID="DIV12" ORDER="12" ORDERLABEL="12" TYPE="PAGE"><hotspots/><resource HEIGHT="2913" ns2:href="URN:NBN:no-nb_digibok_2011110906074_0012" originalName="digibok_2011110906074_0012.jpg" SCANRESOLUTION="400" WIDTH="1712"/></div><div ID="DIV13" ORDER="13" ORDERLABEL="13" TYPE="PAGE"><hotspots/><resource HEIGHT="2914" ns2:href="URN:NBN:no-nb_digibok_2011110906074_0013" originalName="digibok_2011110906074_0013.jpg" SCANRESOLUTION="400" WIDTH="1721"/></div><div ID="DIV14" ORDER="14" ORDERLABEL="14" TYPE="PAGE"><hotspots/><resource HEIGHT="2914" ns2:href="URN:NBN:no-nb_digibok_2011110906074_0014" originalName="digibok_2011110906074_0014.jpg" SCANRESOLUTION="400" WIDTH="1721"/></div><div ID="DIV15" ORDER="15" ORDERLABEL="15" TYPE="PAGE"><hotspots/><resource HEIGHT="2912" ns2:href="URN:NBN:no-nb_digibok_2011110906074_0015" originalName="digibok_2011110906074_0015.jpg" SCANRESOLUTION="400" WIDTH="1710"/></div><div ID="DIV16" ORDER="16" ORDERLABEL="16" TYPE="PAGE"><hotspots/><resource HEIGHT="2912" ns2:href="URN:NBN:no-nb_digibok_2011110906074_0016" originalName="digibok_2011110906074_0016.jpg" SCANRESOLUTION="400" WIDTH="1710"/></div><d ...
